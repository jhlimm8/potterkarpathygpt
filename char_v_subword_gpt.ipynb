# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import tiktoken
import time

# hyperparameters
batch_size = 64 # how many independent sequences will we process in parallel?
block_size = 256 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 50
learning_rate = 3e-4
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 126
n_head = 6
n_layer = 6
dropout = 0.2
tokenizer = 'char'
# ------------

torch.manual_seed(1337)
start_time = time.time()
# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open(r"C:\Users\Lim Jia Hui\Downloads\potter2.txt", 'r', encoding='utf-8') as f:
    text = f.read()

text = text.replace('|',' ')
tokenizer = 'char' # 'tiktoken' for openai bpe tokenizor or 'char' for character tokenizor

if tokenizer == 'tiktoken':
    vocab_size = 50257 #from https://github.com/openai/tiktoken/blob/main/tiktoken_ext/openai_public.py
    bpt_tiktokenizer = tiktoken.get_encoding('gpt2')
    encode = lambda s: [int(bpt_tiktokenizer.encode(c)[0]) for c in s] # encoder: take a string, output a list of integers
    decode = lambda l: ''.join([bpt_tiktokenizer.decode([i]) for i in l]) # decoder: take a list of integers, output a string

elif tokenizer == 'char':
    # here are all the unique characters that occur in this text
    chars = sorted(list(set(text)))
    vocab_size = len(chars)
    # create a mapping from characters to integers
    stoi = { ch:i for i,ch in enumerate(chars) }
    itos = { i:ch for i,ch in enumerate(chars) }
    encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
    decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # input of size (batch, time-step, channels)
        # output of size (batch, time-step, head size)
        B,T,C = x.shape
        k = self.key(x)   # (B,T,hs)
        q = self.query(x) # (B,T,hs)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * k.shape[-1]**-0.5 # (B, T, hs) @ (B, hs, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,hs)
        out = wei @ v # (B, T, T) @ (B, T, hs) -> (B, T, hs)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class GPTLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

        # better init, not covered in the original GPT video, but important, will cover in followup video
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = GPTLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}, time {(time.time() - start_time)//60:.0f}m {(time.time() - start_time) % 60:.2f}s")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=500)[0].tolist()))
# Out:
# 1.202115 M parameters
# step 0: train loss 4.2953, val loss 4.2943, time 0m 27.31s
# step 50: train loss 2.7608, val loss 2.7416, time 1m 4.94s
# step 100: train loss 2.5367, val loss 2.5183, time 1m 46.33s
# step 150: train loss 2.4538, val loss 2.4357, time 2m 29.73s
# step 200: train loss 2.3950, val loss 2.3751, time 3m 13.38s
# step 250: train loss 2.3509, val loss 2.3338, time 3m 57.25s
# step 300: train loss 2.3150, val loss 2.2981, time 4m 41.29s
# step 350: train loss 2.2874, val loss 2.2722, time 5m 25.46s
# step 400: train loss 2.2398, val loss 2.2246, time 6m 9.79s
# step 450: train loss 2.1653, val loss 2.1526, time 7m 22.59s
# step 500: train loss 2.0739, val loss 2.0660, time 8m 6.16s
# step 550: train loss 1.9829, val loss 1.9742, time 8m 50.54s
# step 600: train loss 1.9131, val loss 1.9107, time 10m 8.95s
# step 650: train loss 1.8286, val loss 1.8271, time 10m 52.81s
# step 700: train loss 1.7735, val loss 1.7776, time 11m 37.30s
# step 750: train loss 1.7177, val loss 1.7276, time 12m 55.24s
# step 800: train loss 1.6800, val loss 1.6879, time 13m 39.15s
# step 850: train loss 1.6415, val loss 1.6520, time 14m 23.54s
# step 900: train loss 1.6046, val loss 1.6208, time 15m 41.40s
# step 950: train loss 1.5723, val loss 1.5913, time 16m 25.39s
# step 1000: train loss 1.5546, val loss 1.5736, time 17m 42.96s
# step 1050: train loss 1.5306, val loss 1.5524, time 18m 26.70s
# step 1100: train loss 1.5139, val loss 1.5332, time 19m 40.09s
# step 1150: train loss 1.4945, val loss 1.5144, time 20m 23.54s
# step 1200: train loss 1.4798, val loss 1.5056, time 21m 20.84s
# step 1250: train loss 1.4677, val loss 1.4913, time 22m 25.41s
# step 1300: train loss 1.4507, val loss 1.4744, time 23m 9.75s
# step 1350: train loss 1.4381, val loss 1.4637, time 24m 27.86s
# step 1400: train loss 1.4271, val loss 1.4544, time 25m 11.74s
# step 1450: train loss 1.4118, val loss 1.4391, time 26m 19.14s
# step 1500: train loss 1.4035, val loss 1.4330, time 27m 13.29s
# step 1550: train loss 1.3943, val loss 1.4257, time 27m 57.75s
# step 1600: train loss 1.3893, val loss 1.4163, time 29m 16.00s
# step 1650: train loss 1.3789, val loss 1.4077, time 29m 59.54s
# step 1700: train loss 1.3665, val loss 1.3973, time 31m 17.16s
# step 1750: train loss 1.3577, val loss 1.3926, time 32m 1.16s
# step 1800: train loss 1.3495, val loss 1.3803, time 32m 54.90s
# step 1850: train loss 1.3481, val loss 1.3824, time 34m 7.87s
# step 1900: train loss 1.3396, val loss 1.3710, time 34m 52.31s
# step 1950: train loss 1.3314, val loss 1.3653, time 36m 10.00s
# step 2000: train loss 1.3244, val loss 1.3632, time 36m 53.91s
# step 2050: train loss 1.3157, val loss 1.3512, time 38m 12.01s
# step 2100: train loss 1.3101, val loss 1.3445, time 38m 55.37s
# step 2150: train loss 1.3081, val loss 1.3412, time 39m 39.77s
# step 2200: train loss 1.3021, val loss 1.3371, time 40m 52.87s
# step 2250: train loss 1.2935, val loss 1.3273, time 41m 36.98s
# step 2300: train loss 1.2892, val loss 1.3264, time 42m 59.92s
# step 2350: train loss 1.2838, val loss 1.3212, time 43m 45.50s
# step 2400: train loss 1.2795, val loss 1.3172, time 44m 37.85s
# step 2450: train loss 1.2745, val loss 1.3116, time 45m 51.76s
# step 2500: train loss 1.2666, val loss 1.3069, time 46m 36.32s
# step 2550: train loss 1.2638, val loss 1.3058, time 47m 54.35s
# step 2600: train loss 1.2612, val loss 1.2987, time 48m 38.28s
# step 2650: train loss 1.2609, val loss 1.3027, time 49m 36.44s
# step 2700: train loss 1.2533, val loss 1.2932, time 50m 44.95s
# step 2750: train loss 1.2495, val loss 1.2910, time 51m 29.46s
# step 2800: train loss 1.2464, val loss 1.2885, time 52m 47.10s
# step 2850: train loss 1.2427, val loss 1.2836, time 53m 31.01s
# step 2900: train loss 1.2420, val loss 1.2840, time 54m 15.87s
# step 2950: train loss 1.2356, val loss 1.2786, time 55m 33.84s
# step 3000: train loss 1.2338, val loss 1.2743, time 56m 17.76s
# step 3050: train loss 1.2288, val loss 1.2699, time 57m 7.67s
# step 3100: train loss 1.2277, val loss 1.2668, time 58m 24.64s
# step 3150: train loss 1.2186, val loss 1.2632, time 59m 8.83s
# step 3200: train loss 1.2198, val loss 1.2640, time 60m 26.09s
# step 3250: train loss 1.2144, val loss 1.2619, time 61m 10.19s
# step 3300: train loss 1.2151, val loss 1.2584, time 62m 3.82s
# step 3350: train loss 1.2118, val loss 1.2579, time 63m 16.83s
# step 3400: train loss 1.2100, val loss 1.2556, time 64m 1.17s
# step 3450: train loss 1.2092, val loss 1.2513, time 65m 19.01s
# step 3500: train loss 1.2061, val loss 1.2528, time 66m 2.76s
# step 3550: train loss 1.2014, val loss 1.2465, time 67m 0.21s
# step 3600: train loss 1.1967, val loss 1.2405, time 68m 4.56s
# step 3650: train loss 1.1960, val loss 1.2424, time 69m 3.30s
# step 3700: train loss 1.1928, val loss 1.2406, time 70m 6.38s
# step 3750: train loss 1.1879, val loss 1.2361, time 70m 50.75s
# step 3800: train loss 1.1929, val loss 1.2390, time 72m 8.35s
# step 3850: train loss 1.1862, val loss 1.2345, time 72m 52.28s
# step 3900: train loss 1.1847, val loss 1.2315, time 74m 10.13s
# step 3950: train loss 1.1846, val loss 1.2345, time 74m 53.70s
# step 4000: train loss 1.1827, val loss 1.2318, time 75m 38.21s
# step 4050: train loss 1.1803, val loss 1.2239, time 76m 55.71s
# step 4100: train loss 1.1763, val loss 1.2259, time 77m 39.57s
# step 4150: train loss 1.1735, val loss 1.2202, time 78m 54.44s
# step 4200: train loss 1.1718, val loss 1.2196, time 79m 41.23s
# step 4250: train loss 1.1681, val loss 1.2177, time 80m 25.47s
# step 4300: train loss 1.1728, val loss 1.2198, time 81m 43.43s
# step 4350: train loss 1.1676, val loss 1.2148, time 82m 27.36s
# step 4400: train loss 1.1632, val loss 1.2161, time 83m 45.46s
# step 4450: train loss 1.1654, val loss 1.2151, time 84m 28.96s
# step 4500: train loss 1.1624, val loss 1.2132, time 85m 13.22s
# step 4550: train loss 1.1639, val loss 1.2125, time 86m 31.08s
# step 4600: train loss 1.1602, val loss 1.2051, time 87m 15.03s
# step 4650: train loss 1.1585, val loss 1.2093, time 88m 23.48s
# step 4700: train loss 1.1560, val loss 1.2070, time 89m 16.61s
# step 4750: train loss 1.1523, val loss 1.2019, time 90m 0.96s
# step 4800: train loss 1.1509, val loss 1.1993, time 91m 18.54s
# step 4850: train loss 1.1517, val loss 1.1995, time 92m 2.41s
# step 4900: train loss 1.1526, val loss 1.2004, time 92m 54.97s
# step 4950: train loss 1.1482, val loss 1.1943, time 94m 8.93s
# step 4999: train loss 1.1481, val loss 1.1978, time 94m 52.98s
#  .  Sure said it something soud incle quid leave , “ might you think your ? ”  That said aloney large at Harry .  “ Oh , Your learning , nearly last here , Mr Londam .  You had a suff sort last of it , pleasay did Albo ”  “ Neville’s got in my nin that you’re pave liced ? ”  “ Hagrid did , ” said Riddle growling tack .  He checkould not reall to that a miss bovit back but Stuck Ron All , pure of this Greatonh , fell in him move cellently in singeral picturity tornefrenced the beside to the door t

# %%
# save the model
torch.save(m.state_dict(), r"C:\Users\Lim Jia Hui\Downloads\potterweights.txt")

# %%
# Print model's state_dict
print("Model's state_dict:")
for param_tensor in m.state_dict():
    print(param_tensor, "\t", m.state_dict()[param_tensor].size())
# Out:
# Model's state_dict:
# token_embedding_table.weight 	 torch.Size([75, 126])
# position_embedding_table.weight 	 torch.Size([256, 126])
# blocks.0.sa.heads.0.tril 	 torch.Size([256, 256])
# blocks.0.sa.heads.0.key.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.0.query.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.0.value.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.1.tril 	 torch.Size([256, 256])
# blocks.0.sa.heads.1.key.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.1.query.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.1.value.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.2.tril 	 torch.Size([256, 256])
# blocks.0.sa.heads.2.key.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.2.query.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.2.value.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.3.tril 	 torch.Size([256, 256])
# blocks.0.sa.heads.3.key.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.3.query.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.3.value.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.4.tril 	 torch.Size([256, 256])
# blocks.0.sa.heads.4.key.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.4.query.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.4.value.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.5.tril 	 torch.Size([256, 256])
# blocks.0.sa.heads.5.key.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.5.query.weight 	 torch.Size([21, 126])
# blocks.0.sa.heads.5.value.weight 	 torch.Size([21, 126])
# blocks.0.sa.proj.weight 	 torch.Size([126, 126])
# blocks.0.sa.proj.bias 	 torch.Size([126])
# blocks.0.ffwd.net.0.weight 	 torch.Size([504, 126])
# blocks.0.ffwd.net.0.bias 	 torch.Size([504])
# blocks.0.ffwd.net.2.weight 	 torch.Size([126, 504])
# blocks.0.ffwd.net.2.bias 	 torch.Size([126])
# blocks.0.ln1.weight 	 torch.Size([126])
# blocks.0.ln1.bias 	 torch.Size([126])
# blocks.0.ln2.weight 	 torch.Size([126])
# blocks.0.ln2.bias 	 torch.Size([126])
# blocks.1.sa.heads.0.tril 	 torch.Size([256, 256])
# blocks.1.sa.heads.0.key.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.0.query.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.0.value.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.1.tril 	 torch.Size([256, 256])
# blocks.1.sa.heads.1.key.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.1.query.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.1.value.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.2.tril 	 torch.Size([256, 256])
# blocks.1.sa.heads.2.key.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.2.query.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.2.value.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.3.tril 	 torch.Size([256, 256])
# blocks.1.sa.heads.3.key.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.3.query.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.3.value.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.4.tril 	 torch.Size([256, 256])
# blocks.1.sa.heads.4.key.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.4.query.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.4.value.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.5.tril 	 torch.Size([256, 256])
# blocks.1.sa.heads.5.key.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.5.query.weight 	 torch.Size([21, 126])
# blocks.1.sa.heads.5.value.weight 	 torch.Size([21, 126])
# blocks.1.sa.proj.weight 	 torch.Size([126, 126])
# blocks.1.sa.proj.bias 	 torch.Size([126])
# blocks.1.ffwd.net.0.weight 	 torch.Size([504, 126])
# blocks.1.ffwd.net.0.bias 	 torch.Size([504])
# blocks.1.ffwd.net.2.weight 	 torch.Size([126, 504])
# blocks.1.ffwd.net.2.bias 	 torch.Size([126])
# blocks.1.ln1.weight 	 torch.Size([126])
# blocks.1.ln1.bias 	 torch.Size([126])
# blocks.1.ln2.weight 	 torch.Size([126])
# blocks.1.ln2.bias 	 torch.Size([126])
# blocks.2.sa.heads.0.tril 	 torch.Size([256, 256])
# blocks.2.sa.heads.0.key.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.0.query.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.0.value.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.1.tril 	 torch.Size([256, 256])
# blocks.2.sa.heads.1.key.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.1.query.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.1.value.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.2.tril 	 torch.Size([256, 256])
# blocks.2.sa.heads.2.key.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.2.query.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.2.value.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.3.tril 	 torch.Size([256, 256])
# blocks.2.sa.heads.3.key.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.3.query.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.3.value.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.4.tril 	 torch.Size([256, 256])
# blocks.2.sa.heads.4.key.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.4.query.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.4.value.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.5.tril 	 torch.Size([256, 256])
# blocks.2.sa.heads.5.key.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.5.query.weight 	 torch.Size([21, 126])
# blocks.2.sa.heads.5.value.weight 	 torch.Size([21, 126])
# blocks.2.sa.proj.weight 	 torch.Size([126, 126])
# blocks.2.sa.proj.bias 	 torch.Size([126])
# blocks.2.ffwd.net.0.weight 	 torch.Size([504, 126])
# blocks.2.ffwd.net.0.bias 	 torch.Size([504])
# blocks.2.ffwd.net.2.weight 	 torch.Size([126, 504])
# blocks.2.ffwd.net.2.bias 	 torch.Size([126])
# blocks.2.ln1.weight 	 torch.Size([126])
# blocks.2.ln1.bias 	 torch.Size([126])
# blocks.2.ln2.weight 	 torch.Size([126])
# blocks.2.ln2.bias 	 torch.Size([126])
# blocks.3.sa.heads.0.tril 	 torch.Size([256, 256])
# blocks.3.sa.heads.0.key.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.0.query.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.0.value.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.1.tril 	 torch.Size([256, 256])
# blocks.3.sa.heads.1.key.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.1.query.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.1.value.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.2.tril 	 torch.Size([256, 256])
# blocks.3.sa.heads.2.key.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.2.query.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.2.value.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.3.tril 	 torch.Size([256, 256])
# blocks.3.sa.heads.3.key.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.3.query.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.3.value.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.4.tril 	 torch.Size([256, 256])
# blocks.3.sa.heads.4.key.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.4.query.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.4.value.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.5.tril 	 torch.Size([256, 256])
# blocks.3.sa.heads.5.key.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.5.query.weight 	 torch.Size([21, 126])
# blocks.3.sa.heads.5.value.weight 	 torch.Size([21, 126])
# blocks.3.sa.proj.weight 	 torch.Size([126, 126])
# blocks.3.sa.proj.bias 	 torch.Size([126])
# blocks.3.ffwd.net.0.weight 	 torch.Size([504, 126])
# blocks.3.ffwd.net.0.bias 	 torch.Size([504])
# blocks.3.ffwd.net.2.weight 	 torch.Size([126, 504])
# blocks.3.ffwd.net.2.bias 	 torch.Size([126])
# blocks.3.ln1.weight 	 torch.Size([126])
# blocks.3.ln1.bias 	 torch.Size([126])
# blocks.3.ln2.weight 	 torch.Size([126])
# blocks.3.ln2.bias 	 torch.Size([126])
# blocks.4.sa.heads.0.tril 	 torch.Size([256, 256])
# blocks.4.sa.heads.0.key.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.0.query.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.0.value.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.1.tril 	 torch.Size([256, 256])
# blocks.4.sa.heads.1.key.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.1.query.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.1.value.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.2.tril 	 torch.Size([256, 256])
# blocks.4.sa.heads.2.key.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.2.query.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.2.value.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.3.tril 	 torch.Size([256, 256])
# blocks.4.sa.heads.3.key.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.3.query.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.3.value.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.4.tril 	 torch.Size([256, 256])
# blocks.4.sa.heads.4.key.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.4.query.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.4.value.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.5.tril 	 torch.Size([256, 256])
# blocks.4.sa.heads.5.key.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.5.query.weight 	 torch.Size([21, 126])
# blocks.4.sa.heads.5.value.weight 	 torch.Size([21, 126])
# blocks.4.sa.proj.weight 	 torch.Size([126, 126])
# blocks.4.sa.proj.bias 	 torch.Size([126])
# blocks.4.ffwd.net.0.weight 	 torch.Size([504, 126])
# blocks.4.ffwd.net.0.bias 	 torch.Size([504])
# blocks.4.ffwd.net.2.weight 	 torch.Size([126, 504])
# blocks.4.ffwd.net.2.bias 	 torch.Size([126])
# blocks.4.ln1.weight 	 torch.Size([126])
# blocks.4.ln1.bias 	 torch.Size([126])
# blocks.4.ln2.weight 	 torch.Size([126])
# blocks.4.ln2.bias 	 torch.Size([126])
# blocks.5.sa.heads.0.tril 	 torch.Size([256, 256])
# blocks.5.sa.heads.0.key.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.0.query.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.0.value.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.1.tril 	 torch.Size([256, 256])
# blocks.5.sa.heads.1.key.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.1.query.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.1.value.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.2.tril 	 torch.Size([256, 256])
# blocks.5.sa.heads.2.key.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.2.query.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.2.value.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.3.tril 	 torch.Size([256, 256])
# blocks.5.sa.heads.3.key.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.3.query.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.3.value.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.4.tril 	 torch.Size([256, 256])
# blocks.5.sa.heads.4.key.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.4.query.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.4.value.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.5.tril 	 torch.Size([256, 256])
# blocks.5.sa.heads.5.key.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.5.query.weight 	 torch.Size([21, 126])
# blocks.5.sa.heads.5.value.weight 	 torch.Size([21, 126])
# blocks.5.sa.proj.weight 	 torch.Size([126, 126])
# blocks.5.sa.proj.bias 	 torch.Size([126])
# blocks.5.ffwd.net.0.weight 	 torch.Size([504, 126])
# blocks.5.ffwd.net.0.bias 	 torch.Size([504])
# blocks.5.ffwd.net.2.weight 	 torch.Size([126, 504])
# blocks.5.ffwd.net.2.bias 	 torch.Size([126])
# blocks.5.ln1.weight 	 torch.Size([126])
# blocks.5.ln1.bias 	 torch.Size([126])
# blocks.5.ln2.weight 	 torch.Size([126])
# blocks.5.ln2.bias 	 torch.Size([126])
# ln_f.weight 	 torch.Size([126])
# ln_f.bias 	 torch.Size([126])
# lm_head.weight 	 torch.Size([75, 126])
# lm_head.bias 	 torch.Size([75])

# %%
open(r"C:\Users\Lim Jia Hui\Downloads\morepotter.txt", 'w').write(decode(m.generate(context, max_new_tokens=10000)[0].tolist()))
# Out:
# 10001
